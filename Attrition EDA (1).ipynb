# %% [markdown]
# ##  Team 17 IML Attrition Analysis

# %%
import os
os.chdir("C:\\Users\\pallavi.chagi\\Downloads\\Python")

#Read the cars.csv data
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
emp = pd.read_csv("attrition.csv")

# %%
emp.head().T
# Out:
#                                      0                       1  \
# Age                                 41                      49
# Attrition                            1                       0
# BusinessTravel           Travel_Rarely       Travel_Frequently
# Department                       Sales  Research & Development
# EducationField           Life Sciences           Life Sciences
# EnvironmentSatisfaction              2                       3
# Gender                          Female                    Male
# JobInvolvement                       3                       2
# JobLevel                             2                       2
# JobSatisfaction                      4                       2
# MaritalStatus                   Single                 Married
# MonthlyIncome                     5993                    5130
# OverTime                           Yes                      No
# TotalWorkingYears                    8                      10
# WorkLifeBalance                      1                       3
# YearsAtCompany                       6                      10
# YearsInCurrentRole                   4                       7
# YearsSinceLastPromotion              0                       1
# YearsWithCurrManager                 5                       7
# DistanceFromHome                     1                       8
#
#                                               2                       3  \
# Age                                          37                      33
# Attrition                                     1                       0
# BusinessTravel                    Travel_Rarely       Travel_Frequently
# Department               Research & Development  Research & Development
# EducationField                            Other           Life Sciences
# EnvironmentSatisfaction                       4                       4
# Gender                                     Male                  Female
# JobInvolvement                                2                       3
# JobLevel                                      1                       1
# JobSatisfaction                               3                       3
# MaritalStatus                            Single                 Married
# MonthlyIncome                              2090                    2909
# OverTime                                    Yes                     Yes
# TotalWorkingYears                             7                       8
# WorkLifeBalance                               3                       3
# YearsAtCompany                                0                       8
# YearsInCurrentRole                            0                       7
# YearsSinceLastPromotion                       0                       3
# YearsWithCurrManager                          0                       0
# DistanceFromHome                              2                       3
#
#                                               4
# Age                                          27
# Attrition                                     0
# BusinessTravel                    Travel_Rarely
# Department               Research & Development
# EducationField                          Medical
# EnvironmentSatisfaction                       1
# Gender                                     Male
# JobInvolvement                                3
# JobLevel                                      1
# JobSatisfaction                               2
# MaritalStatus                           Married
# MonthlyIncome                              3468
# OverTime                                     No
# TotalWorkingYears                             6
# WorkLifeBalance                               3
# YearsAtCompany                                2
# YearsInCurrentRole                            2
# YearsSinceLastPromotion                       2
# YearsWithCurrManager                          2
# DistanceFromHome                              2

# %%
emp.shape #no. of rows and columns
# Out:
# (1470, 20)

# %%
emp.dtypes    #All columns and their data types
# Out:
# Age                         int64
# Attrition                   int64
# BusinessTravel             object
# Department                 object
# EducationField             object
# EnvironmentSatisfaction     int64
# Gender                     object
# JobInvolvement              int64
# JobLevel                    int64
# JobSatisfaction             int64
# MaritalStatus              object
# MonthlyIncome               int64
# OverTime                   object
# TotalWorkingYears           int64
# WorkLifeBalance             int64
# YearsAtCompany              int64
# YearsInCurrentRole          int64
# YearsSinceLastPromotion     int64
# YearsWithCurrManager        int64
# DistanceFromHome            int64
# dtype: object

# %%
emp['Attrition'].value_counts()
# Out:
# 0    1233
# 1     237
# Name: Attrition, dtype: int64

# %%
tab = pd.crosstab(emp.Attrition, columns="Attrition")
tab
# Out:
# col_0      Attrition
# Attrition
# 0               1233
# 1                237

# %%
n = len(emp)
round(tab/n*100,2)
# Out:
# col_0      Attrition
# Attrition
# 0              83.88
# 1              16.12

# %%
emp.isnull().sum() #Finding null values. 
                   #For the record there are no null values
# Out:
# Age                        0
# Attrition                  0
# BusinessTravel             0
# Department                 0
# EducationField             0
# EnvironmentSatisfaction    0
# Gender                     0
# JobInvolvement             0
# JobLevel                   0
# JobSatisfaction            0
# MaritalStatus              0
# MonthlyIncome              0
# OverTime                   0
# TotalWorkingYears          0
# WorkLifeBalance            0
# YearsAtCompany             0
# YearsInCurrentRole         0
# YearsSinceLastPromotion    0
# YearsWithCurrManager       0
# DistanceFromHome           0
# dtype: int64

# %%
emp.describe()
# Out:
#                Age    Attrition  EnvironmentSatisfaction  JobInvolvement  \
# count  1470.000000  1470.000000              1470.000000     1470.000000
# mean     36.923810     0.161224                 2.721769        2.729932
# std       9.135373     0.367863                 1.093082        0.711561
# min      18.000000     0.000000                 1.000000        1.000000
# 25%      30.000000     0.000000                 2.000000        2.000000
# 50%      36.000000     0.000000                 3.000000        3.000000
# 75%      43.000000     0.000000                 4.000000        3.000000
# max      60.000000     1.000000                 4.000000        4.000000
#
#           JobLevel  JobSatisfaction  MonthlyIncome  TotalWorkingYears  \
# count  1470.000000      1470.000000    1470.000000        1470.000000
# mean      2.063946         2.728571    6502.931293          11.279592
# std       1.106940         1.102846    4707.956783           7.780782
# min       1.000000         1.000000    1009.000000           0.000000
# 25%       1.000000         2.000000    2911.000000           6.000000
# 50%       2.000000         3.000000    4919.000000          10.000000
# 75%       3.000000         4.000000    8379.000000          15.000000
# max       5.000000         4.000000   19999.000000          40.000000
#
#        WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# count      1470.000000     1470.000000         1470.000000
# mean          2.761224        7.008163            4.229252
# std           0.706476        6.126525            3.623137
# min           1.000000        0.000000            0.000000
# 25%           2.000000        3.000000            2.000000
# 50%           3.000000        5.000000            3.000000
# 75%           3.000000        9.000000            7.000000
# max           4.000000       40.000000           18.000000
#
#        YearsSinceLastPromotion  YearsWithCurrManager  DistanceFromHome
# count              1470.000000           1470.000000       1470.000000
# mean                  2.187755              4.123129          9.192517
# std                   3.222430              3.568136          8.106864
# min                   0.000000              0.000000          1.000000
# 25%                   0.000000              2.000000          2.000000
# 50%                   1.000000              3.000000          7.000000
# 75%                   3.000000              7.000000         14.000000
# max                  15.000000             17.000000         29.000000

# %% [markdown]
# Bi-Variate Analysis of Numerical Columns

# %% [markdown]
# 1. Age

# %%
# Frequency distribution of age with attrtion status
plt.figure(figsize = (15, 7), dpi = 100)
sns.countplot(x='Age', hue='Attrition', data=emp,
            palette=['purple', 'steelblue'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %%
#KDE plot of age and attrition status

df = emp[emp.Attrition == 0]
sns.distplot(df['Age'], hist = True, kde = True, label='0')
df = emp[emp.Attrition == 1]
sns.distplot(df['Age'], hist = True, kde = True, label='1')
plt.legend(prop={'size': 12})
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# 1.From the above plot we can see that as a person's age is low, the probabilty of leaving the organization is more than probability of statying, but as the age reaches approximately 33 the probability of staying in the organization is more than probabilty of leaving.
#
# 2.We can also see that the maximum number of employees leaving is in the age range of 28-32
#
# 3. From the frequency plot we can see that the attrtion rate among the yonger workforce is  roughly 50%(in a particular age
#    there are as many people staying as leaving), but as we move to the mid-age and old workforce this trend is notfollowed.

# %% [markdown]
# 2. Monthly Income

# %%
#KDE plot of monthly income and attrition status

df = emp[emp.Attrition == 0]
sns.distplot(df['MonthlyIncome'], hist = True, kde = True, label='0')
df = emp[emp.Attrition == 1]
sns.distplot(df['MonthlyIncome'], hist = True, kde = True, label='1')
plt.legend(prop={'size': 12})
# Out:
# C:\Users\pallavi.chagi\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\pallavi.chagi\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# 1.From the above plot we can see that as a person's monthly is low, the probabilty of leaving the organization is more than probability of statying, but as the monthly income reaches approximately 10000 the probability of staying in the organization is more than probabilty of leaving.
#
# 2.We can also see that the maximum number of employees leaving is in the income range of 2000-3000

# %%
#Scatter plot of age vs monthly income

emp.plot(kind="scatter",
         x="Age", y = "MonthlyIncome",
         color = "green",
         figsize=(8,7))

plt.xlabel("Age", fontsize=12)
plt.ylabel("MonthlyIncome", fontsize=12)
plt.title("Scatter Plot", fontsize=14)

plt.show()

# %% [markdown]
# It is evident from the scatter plot that very young employees(18-20) have the minumum monthly income and that could be a reason that they have high probability of leaving.

# %% [markdown]
# 3. Total Working years

# %%
#Frequency plot of Total working years and attrition status
plt.figure(figsize = (15, 7), dpi = 100)
sns.countplot(x='TotalWorkingYears', hue='Attrition', data=emp,
            palette=['purple', 'steelblue'])
# Out:
# <AxesSubplot:xlabel='TotalWorkingYears', ylabel='count'>

# %%
#We can see that attrtion is highest amongst the low experience employees(0-1 years) who have just started and as an employee moves 
# gains suffcient work-ex, the attrition rate reduces significantly.

# %%
df = emp[emp.Attrition == 0]
sns.distplot(df['TotalWorkingYears'], hist = True, kde = True, label='0')
df = emp[emp.Attrition == 1]
sns.distplot(df['TotalWorkingYears'], hist = True, kde = True, label='1')
plt.legend(prop={'size': 12})
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# 1.From the above plot we can see that as a person's work experince is low, the probabilty of leaving the organization is more than probability of statying, but as the work-ex reaches approximately 8 years the probability of staying in the organization is more than probabilty of leaving.
#
# 2.We can also see that the maximum number of employees leaving have 1 year of work ex.

# %%
#Scatter plot of Monthly Income vs Total years of work ex
emp.plot(kind="scatter",
         x="TotalWorkingYears", y = "MonthlyIncome",
         color = "green",
         figsize=(8,7))

plt.xlabel("TotalWorkingYears", fontsize=12)
plt.ylabel("MonthlyIncome", fontsize=12)
plt.title("Scatter Plot", fontsize=14)

plt.show()

# %%
# Assumption - Employees who are freshers have very low monthly wage.

# Prove - From the scatter plot we can see that those with 0-1 years of work ex are earning the lowest monthly income in the company

# %% [markdown]
# 4. Years At Company

# %%
#Frequency plot of Total working years and attrition status
plt.figure(figsize = (15, 7), dpi = 100)
sns.countplot(x='YearsAtCompany', hue='Attrition', data=emp,
            palette=['purple', 'steelblue'])
# Out:
# <AxesSubplot:xlabel='YearsAtCompany', ylabel='count'>

# %%
df = emp[emp.Attrition == 0]
sns.distplot(df['YearsAtCompany'], hist = True, kde = True, label='0')
df = emp[emp.Attrition == 1]
sns.distplot(df['YearsAtCompany'], hist = True, kde = True, label='1')
plt.legend(prop={'size': 12})
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# 5.YearsInCurrentRole

# %%
#Frequency plot of Total working years and attrition status
plt.figure(figsize = (15, 7), dpi = 100)
sns.countplot(x='YearsInCurrentRole', hue='Attrition', data=emp,
            palette=['purple', 'steelblue'])
# Out:
# <AxesSubplot:xlabel='YearsInCurrentRole', ylabel='count'>

# %%
df = emp[emp.Attrition == 0]
sns.distplot(df['YearsInCurrentRole'], hist = True, kde = True, label='0')
df = emp[emp.Attrition == 1]
sns.distplot(df['YearsInCurrentRole'], hist = True, kde = True, label='1')
plt.legend(prop={'size': 12})
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# 6.YearsSinceLastPromotion

# %%
#Frequency plot of YearsSinceLastPromotion and attrition status
plt.figure(figsize = (15, 7), dpi = 100)
sns.countplot(x='YearsSinceLastPromotion', hue='Attrition', data=emp,
            palette=['purple', 'steelblue'])
# Out:
# <AxesSubplot:xlabel='YearsSinceLastPromotion', ylabel='count'>

# %%
df = emp[emp.Attrition == 0]
sns.distplot(df['YearsSinceLastPromotion'], hist = True, kde = True, label='0')
df = emp[emp.Attrition == 1]
sns.distplot(df['YearsSinceLastPromotion'], hist = True, kde = True, label='1')
plt.legend(prop={'size': 12})
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# 7.YearsWithCurrManager

# %%
#Frequency plot of YearsSinceLastPromotion and attrition status
plt.figure(figsize = (15, 7), dpi = 100)
sns.countplot(x='YearsWithCurrManager', hue='Attrition', data=emp,
            palette=['purple', 'steelblue'])
# Out:
# <AxesSubplot:xlabel='YearsWithCurrManager', ylabel='count'>

# %%
df = emp[emp.Attrition == 0]
sns.distplot(df['YearsWithCurrManager'], hist = True, kde = True, label='0')
df = emp[emp.Attrition == 1]
sns.distplot(df['YearsWithCurrManager'], hist = True, kde = True, label='1')
plt.legend(prop={'size': 12})
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Bi-Variate and multi-variate analysis of categorical column

# %% [markdown]
# 1. Gender

# %%
#Frequency table of Gender
plt.figure(figsize = (9, 5), dpi = 100)
sns.countplot(x='Gender', data=emp,
            palette=['purple', 'steelblue'])
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
#More males working in the company than females

# %%
##Frequency table of Gender with atrrtion status
plt.figure(figsize = (9, 5), dpi = 100)
sns.countplot(x='Gender', hue='Attrition', data=emp,
            palette=['purple', 'steelblue'])
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
#Conditional probabilty table conditioned on columns
table = pd.crosstab(emp.Attrition,columns=emp.Gender)
coltotal = table.sum(axis=0)
table.div(coltotal,axis=1)
# Out:
# Gender       Female      Male
# Attrition
# 0          0.852041  0.829932
# 1          0.147959  0.170068

# %%
#From the conditional probabilty table we can see that male employees have high probabilty of leaving as compared to female
#employees but the difference is very small so we can say that gender doesn't has a significant role in attrition.

# %% [markdown]
# 2.BusinessTravel

# %%
#Frequency table of BusinessTravel
plt.figure(figsize = (9, 5), dpi = 100)
sns.countplot(x='BusinessTravel', data=emp,
            palette=['purple', 'steelblue'])
# Out:
# <AxesSubplot:xlabel='BusinessTravel', ylabel='count'>

# %%
#Majority of the employees don't travel on work.

# %%
##Frequency table of BusinessTravel with atrrtion status
plt.figure(figsize = (9, 5), dpi = 100)
sns.countplot(x='BusinessTravel', hue='Attrition', data=emp,
            palette=['purple', 'steelblue'])
# Out:
# <AxesSubplot:xlabel='BusinessTravel', ylabel='count'>

# %%
#From the above plot we can see that the attrtition is lowest among employees who don't travel. It could be that employees
#don't like traveling.

# %%
#Conditional probabilty table conditioned on columns
table = pd.crosstab(emp.Attrition,columns=emp.BusinessTravel)
coltotal = table.sum(axis=0)
table.div(coltotal,axis=1)
# Out:
# BusinessTravel  Non-Travel  Travel_Frequently  Travel_Rarely
# Attrition
# 0                     0.92           0.750903       0.850431
# 1                     0.08           0.249097       0.149569

# %%
#From the conditional probailty table it is evident that the probaility of leaving is highest for employees who travel
#frequently(0.24) and lowest for those who never travel(0.08). Employees of this company don't like traveling and it could
#be a reason they are leaving. This factor has a significant impact on attrtion

# %% [markdown]
# 3.EnvironmentSatisfaction

# %%
#Frequency table of EnvironmentSatisfaction
plt.figure(figsize = (9, 5), dpi = 100)
sns.countplot(x='EnvironmentSatisfaction', data=emp,
            palette=['purple', 'steelblue'])
# Out:
# <AxesSubplot:xlabel='EnvironmentSatisfaction', ylabel='count'>

# %%
# From the above plot we can say that majority of the employees in the company are satisfied with the enviroment.

# %%
#Frequency table of EnvironmentSatisfaction with atrrtion status
plt.figure(figsize = (9, 5), dpi = 100)
sns.countplot(x='EnvironmentSatisfaction', hue='Attrition', data=emp,
            palette=['purple', 'steelblue'])
# Out:
# <AxesSubplot:xlabel='EnvironmentSatisfaction', ylabel='count'>

# %%
#From the above plot we can say that maximum attrition is for people who are not very happy in the company.

# %%
#Conditional probabilty table conditioned on columns
table = pd.crosstab(emp.Attrition,columns=emp.EnvironmentSatisfaction)
coltotal = table.sum(axis=0)
table.div(coltotal,axis=1)
# Out:
# EnvironmentSatisfaction         1         2         3         4
# Attrition
# 0                        0.746479  0.850174  0.863135  0.865471
# 1                        0.253521  0.149826  0.136865  0.134529

# %%
#From the conditional probability table we can say that given that a person is not very happy with the enviroment(1),he/she 
#has high probabilty of leaving(0.25).
#For levels 2 and 3 the probabilty of leaving is almost equal hence only people who are very unhappy with enviroment tend 
#to leave.

# %% [markdown]
# 4.JobInvolvement

# %%
#Frequency table of JobInvolvement
plt.figure(figsize = (9, 5), dpi = 100)
sns.countplot(x='JobInvolvement', data=emp,
            palette=['purple', 'steelblue'])
# Out:
# <AxesSubplot:xlabel='JobInvolvement', ylabel='count'>

# %%
# From the above plot we can say that majority of the employees in the company feel connected with their work.

# %%
##Frequency table of JobInvolvement with atrrtion status
plt.figure(figsize = (9, 5), dpi = 100)
sns.countplot(x='JobInvolvement', hue='Attrition', data=emp,
            palette=['purple', 'steelblue'])
# Out:
# <AxesSubplot:xlabel='JobInvolvement', ylabel='count'>

# %%
#Conditional probabilty table conditioned on columns
table = pd.crosstab(emp.Attrition,columns=emp.JobInvolvement)
coltotal = table.sum(axis=0)
table.div(coltotal,axis=1)
# Out:
# JobInvolvement         1         2         3         4
# Attrition
# 0               0.662651  0.810667  0.855991  0.909722
# 1               0.337349  0.189333  0.144009  0.090278

# %%
#From the conditional probability table we can say that given that a person is not very much
#involved with the job( level 1 ),he/she has high probabilty of leaving(0.33).
#From level 2 this probabilty decreases and is least for employees who have job level 4. This is a major factor.

# %% [markdown]
# 5.JobLevel

# %%
#Frequency table of JobLevel
plt.figure(figsize = (9, 5), dpi = 100)
sns.countplot(x='JobLevel', data=emp,
            palette=['purple', 'steelblue'])
# Out:
# <AxesSubplot:xlabel='JobLevel', ylabel='count'>

# %%
#Majority of the employees are in the job level 1. They could be low aged and low experinced.

# %%
##Frequency table of JobLevel with atrrtion status
plt.figure(figsize = (9, 5), dpi = 100)
sns.countplot(x='JobLevel', hue='Attrition', data=emp,
            palette=['purple', 'steelblue'])
# Out:
# <AxesSubplot:xlabel='JobLevel', ylabel='count'>

# %%
#Attrition is maximum in people who are in job level 1.

# %%
#Conditional probabilty table conditioned on columns
table = pd.crosstab(emp.Attrition,columns=emp.JobLevel)
coltotal = table.sum(axis=0)
table.div(coltotal,axis=1)
# Out:
# JobLevel          1         2         3        4         5
# Attrition
# 0          0.736648  0.902622  0.853211  0.95283  0.927536
# 1          0.263352  0.097378  0.146789  0.04717  0.072464

# %%
#From the conditional probability table we can say that given that a person is in job level 1,he/she 
#has high probabilty of leaving(0.26).
#For levels 2 and 3 the probabilty of leaving is low(0.1 and 0.14) as compared to  job level 1. For job levels
#4 and 5 the probabilty of leaving decreases significantly. So employee who are at intial stage of career in this 
#organization tend to leave.

# %%
#Scatter plot of Monthly Income vs Job level
emp.plot(kind="scatter",
         x="JobLevel", y = "MonthlyIncome",
         color = "green",
         figsize=(8,7))

plt.xlabel("JobLevel", fontsize=12)
plt.ylabel("MonthlyIncome", fontsize=12)
plt.title("Scatter Plot", fontsize=14)

plt.show()

# %%
#As expected, the employees in job level 1 are least paid and that could be the reason they have high chance of leaving.
#When we see job level 5, these guys are highly paid and they have least chance of leaving. We are getting a connection
#over here that income is very important for employees of this organisation.

# %% [markdown]
# 6.JobSatisfaction

# %%
#Frequency table of JobSatisfaction
plt.figure(figsize = (9, 5), dpi = 100)
sns.countplot(x='JobSatisfaction', data=emp,
            palette=['purple', 'steelblue'])
# Out:
# <AxesSubplot:xlabel='JobSatisfaction', ylabel='count'>

# %%
#Majority of the people are satisfied with their job.

# %%
##Frequency table ofJobSatisfaction with atrrtion status
plt.figure(figsize = (9, 5), dpi = 100)
sns.countplot(x='JobSatisfaction', hue='Attrition', data=emp,
            palette=['purple', 'steelblue'])
# Out:
# <AxesSubplot:xlabel='JobSatisfaction', ylabel='count'>

# %%
#Conditional probabilty table conditioned on columns
table = pd.crosstab(emp.Attrition,columns=emp.JobSatisfaction)
coltotal = table.sum(axis=0)
table.div(coltotal,axis=1)
# Out:
# JobSatisfaction         1         2         3        4
# Attrition
# 0                0.771626  0.835714  0.834842  0.88671
# 1                0.228374  0.164286  0.165158  0.11329

# %%
#From the conditional probability table we can say that given that a person is very dissatisfied with the job, there is 
#0.22 probabilty that the person will leave the organisation. But as the job satisfaction increases the probabilty of 
#leaving decreases. This is a major factor.

# %%
sns.scatterplot(emp['JobLevel'],emp['MonthlyIncome'],hue=emp['Attrition'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='JobLevel', ylabel='MonthlyIncome'>

# %% [markdown]
# 7.MaritalStatus

# %%
#Frequency table of MaritalStatus
plt.figure(figsize = (9, 5), dpi = 100)
sns.countplot(x='MaritalStatus', data=emp,
            palette=['purple', 'steelblue'])
# Out:
# <AxesSubplot:xlabel='MaritalStatus', ylabel='count'>

# %%
#Maximum people in the company are married.

# %%
##Frequency table of MaritalStatus with atrrtion status
plt.figure(figsize = (9, 5), dpi = 100)
sns.countplot(x='MaritalStatus', hue='Attrition', data=emp,
            palette=['purple', 'steelblue'])
# Out:
# <AxesSubplot:xlabel='MaritalStatus', ylabel='count'>

# %%
#Conditional probabilty table conditioned on columns
table = pd.crosstab(emp.Attrition,columns=emp.MaritalStatus)
coltotal = table.sum(axis=0)
table.div(coltotal,axis=1)
# Out:
# MaritalStatus  Divorced   Married    Single
# Attrition
# 0              0.899083  0.875186  0.744681
# 1              0.100917  0.124814  0.255319

# %%
#From the conditional probability table we can say that given that a person is single, there is 0.25 probabilty that the
#person will leave the organisation. But when we see the married and divorced employees, the probabilty is quiet low.
#Married people are less likely to leave maybe because of job security and responsibilites they have.

# %% [markdown]
# 8.OverTime

# %%
#Frequency table of OverTime
plt.figure(figsize = (9, 5), dpi = 100)
sns.countplot(x='OverTime', data=emp,
            palette=['purple', 'steelblue'])
# Out:
# <AxesSubplot:xlabel='OverTime', ylabel='count'>

# %%
#From the above plot it is evident that more than 50% of the employees don't work overtime.

# %%
##Frequency table of OverTime with atrrtion status
plt.figure(figsize = (9, 5), dpi = 100)
sns.countplot(x='OverTime', hue='Attrition', data=emp,
            palette=['purple', 'steelblue'])
# Out:
# <AxesSubplot:xlabel='OverTime', ylabel='count'>

# %%
#Attriton is maximum for employees working overtime and if we look at the percentage of people leaving who are working
#overtime, the percentage is very high as compared to percentage of employees not working overtime and leaving.
#It could be true that working overtime is a reason for leaving, let's understand that.

# %%
#Conditional probabilty table conditioned on columns
table = pd.crosstab(emp.Attrition,columns=emp.OverTime)
coltotal = table.sum(axis=0)
table.div(coltotal,axis=1)
# Out:
# OverTime         No       Yes
# Attrition
# 0          0.895636  0.694712
# 1          0.104364  0.305288

# %%
#From the conditional probabilty table we can say that given that an employee is working overtime, there is high 
#probabilty(0.30) that the person will leave. This factor is affecting attrtiton significantly and employees are not happy
#woprking overtime.

# %% [markdown]
# 9.Department

# %%
#Frequency table of .Department
plt.figure(figsize = (9, 5), dpi = 100)
sns.countplot(x='Department', data=emp,
            palette=['purple', 'steelblue'])
# Out:
# <AxesSubplot:xlabel='Department', ylabel='count'>

# %%
##Frequency table of .Department with atrrtion status
plt.figure(figsize = (9, 5), dpi = 100)
sns.countplot(x='Department', hue='Attrition', data=emp,
            palette=['purple', 'steelblue'])
# Out:
# <AxesSubplot:xlabel='Department', ylabel='count'>

# %%
#Conditional probabilty table conditioned on columns
table = pd.crosstab(emp.Attrition,columns=emp.Department)
coltotal = table.sum(axis=0)
table.div(coltotal,axis=1)
# Out:
# Department  Human Resources  Research & Development     Sales
# Attrition
# 0                  0.809524                0.861602  0.793722
# 1                  0.190476                0.138398  0.206278

# %% [markdown]
# 10.EducationField

# %%
#Frequency table of EducationField
plt.figure(figsize = (9, 5), dpi = 100)
sns.countplot(x='EducationField', data=emp,
            palette=['purple', 'steelblue'])
# Out:
# <AxesSubplot:xlabel='EducationField', ylabel='count'>

# %%
##Frequency table of EducationField with atrrtion status
plt.figure(figsize = (9, 5), dpi = 100)
sns.countplot(x='EducationField', hue='Attrition', data=emp,
            palette=['purple', 'steelblue'])
# Out:
# <AxesSubplot:xlabel='EducationField', ylabel='count'>

# %%
#Conditional probabilty table conditioned on columns
table = pd.crosstab(emp.Attrition,columns=emp.EducationField)
coltotal = table.sum(axis=0)
table.div(coltotal,axis=1)
# Out:
# EducationField  Human Resources  Life Sciences  Marketing   Medical     Other  \
# Attrition
# 0                      0.740741       0.853135   0.779874  0.864224  0.865854
# 1                      0.259259       0.146865   0.220126  0.135776  0.134146
#
# EducationField  Technical Degree
# Attrition
# 0                       0.757576
# 1                       0.242424

# %%
tab = pd.crosstab(emp.Gender,columns='Frequency')
tab

# %%
table = pd.crosstab(emp.Gender,columns=emp.Attrition)
table
# Out:
# Attrition    0    1
# Gender
# Female     501   87
# Male       732  150

# %%
tab = pd.crosstab(emp.BusinessTravel,columns='Frequency')
tab
# Out:
# col_0              Frequency
# BusinessTravel
# Non-Travel               150
# Travel_Frequently        277
# Travel_Rarely           1043

# %%
tab = pd.crosstab(emp.Department,columns='Frequency')
tab
# Out:
# col_0                   Frequency
# Department
# Human Resources                63
# Research & Development        961
# Sales                         446

# %%
tab = pd.crosstab(emp.Department,columns=emp.Attrition)
tab
# Out:
# Attrition                 0    1
# Department
# Human Resources          51   12
# Research & Development  828  133
# Sales                   354   92

# %%
corr=emp.corr()
corr.style.background_gradient()
# Out:
# <style type="text/css">
# #T_24242_row0_col0, #T_24242_row1_col1, #T_24242_row2_col2, #T_24242_row3_col3, #T_24242_row4_col4, #T_24242_row5_col5, #T_24242_row6_col6, #T_24242_row7_col7, #T_24242_row8_col8, #T_24242_row9_col9, #T_24242_row10_col10, #T_24242_row11_col11, #T_24242_row12_col12, #T_24242_row13_col13 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_24242_row0_col1, #T_24242_row2_col13, #T_24242_row3_col11, #T_24242_row6_col1, #T_24242_row6_col13, #T_24242_row10_col1 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_24242_row0_col2, #T_24242_row1_col13, #T_24242_row3_col9, #T_24242_row4_col3, #T_24242_row6_col3, #T_24242_row8_col3 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_24242_row0_col3, #T_24242_row2_col7, #T_24242_row3_col7, #T_24242_row5_col4 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_24242_row0_col4, #T_24242_row9_col6 {
#   background-color: #4c99c5;
#   color: #f1f1f1;
# }
# #T_24242_row0_col5, #T_24242_row2_col5, #T_24242_row2_col8, #T_24242_row3_col2, #T_24242_row5_col2, #T_24242_row6_col2, #T_24242_row6_col5, #T_24242_row6_col8, #T_24242_row12_col2 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_24242_row0_col6, #T_24242_row6_col0 {
#   background-color: #529bc7;
#   color: #f1f1f1;
# }
# #T_24242_row0_col7 {
#   background-color: #0d75b3;
#   color: #f1f1f1;
# }
# #T_24242_row0_col8, #T_24242_row5_col8, #T_24242_row8_col11, #T_24242_row12_col13, #T_24242_row13_col11 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_24242_row0_col9 {
#   background-color: #9fbad9;
#   color: #000000;
# }
# #T_24242_row0_col10, #T_24242_row10_col0, #T_24242_row11_col0 {
#   background-color: #b8c6e0;
#   color: #000000;
# }
# #T_24242_row0_col11 {
#   background-color: #d2d3e7;
#   color: #000000;
# }
# #T_24242_row0_col12, #T_24242_row12_col0 {
#   background-color: #bcc7e1;
#   color: #000000;
# }
# #T_24242_row0_col13 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_24242_row1_col0, #T_24242_row1_col2, #T_24242_row1_col3, #T_24242_row1_col4, #T_24242_row1_col5, #T_24242_row1_col6, #T_24242_row1_col7, #T_24242_row1_col8, #T_24242_row1_col9, #T_24242_row1_col10, #T_24242_row1_col11, #T_24242_row1_col12, #T_24242_row4_col1, #T_24242_row7_col1, #T_24242_row8_col13 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_24242_row2_col0, #T_24242_row2_col4, #T_24242_row3_col10, #T_24242_row8_col7, #T_24242_row13_col4, #T_24242_row13_col7, #T_24242_row13_col12 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_24242_row2_col1, #T_24242_row5_col1 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_24242_row2_col3, #T_24242_row10_col8, #T_24242_row11_col2 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# #T_24242_row2_col6, #T_24242_row2_col12, #T_24242_row5_col6, #T_24242_row8_col9 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_24242_row2_col9, #T_24242_row8_col0, #T_24242_row8_col2, #T_24242_row11_col1 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_24242_row2_col10, #T_24242_row13_col10 {
#   background-color: #e6e2ef;
#   color: #000000;
# }
# #T_24242_row2_col11, #T_24242_row3_col8, #T_24242_row10_col13 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_24242_row3_col0 {
#   background-color: #e4e1ef;
#   color: #000000;
# }
# #T_24242_row3_col1, #T_24242_row3_col13, #T_24242_row9_col1, #T_24242_row9_col13, #T_24242_row13_col8 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_24242_row3_col4, #T_24242_row5_col0, #T_24242_row5_col10, #T_24242_row13_col0 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_24242_row3_col5, #T_24242_row7_col5, #T_24242_row8_col5, #T_24242_row11_col5 {
#   background-color: #f4edf6;
#   color: #000000;
# }
# #T_24242_row3_col6, #T_24242_row10_col3, #T_24242_row13_col3, #T_24242_row13_col6 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# #T_24242_row3_col12 {
#   background-color: #e5e1ef;
#   color: #000000;
# }
# #T_24242_row4_col0, #T_24242_row11_col12 {
#   background-color: #4e9ac6;
#   color: #f1f1f1;
# }
# #T_24242_row4_col2, #T_24242_row4_col8, #T_24242_row5_col3, #T_24242_row9_col2, #T_24242_row9_col3 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_24242_row4_col5, #T_24242_row7_col2, #T_24242_row8_col1, #T_24242_row9_col5, #T_24242_row10_col5, #T_24242_row11_col3, #T_24242_row13_col5 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_24242_row4_col6, #T_24242_row6_col4 {
#   background-color: #034369;
#   color: #f1f1f1;
# }
# #T_24242_row4_col7, #T_24242_row7_col4 {
#   background-color: #04649e;
#   color: #f1f1f1;
# }
# #T_24242_row4_col9 {
#   background-color: #4697c4;
#   color: #f1f1f1;
# }
# #T_24242_row4_col10 {
#   background-color: #7eadd1;
#   color: #f1f1f1;
# }
# #T_24242_row4_col11 {
#   background-color: #a7bddb;
#   color: #000000;
# }
# #T_24242_row4_col12 {
#   background-color: #84b0d3;
#   color: #f1f1f1;
# }
# #T_24242_row4_col13, #T_24242_row7_col13 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_24242_row5_col7, #T_24242_row13_col9 {
#   background-color: #ece7f2;
#   color: #000000;
# }
# #T_24242_row5_col9 {
#   background-color: #eee8f3;
#   color: #000000;
# }
# #T_24242_row5_col11, #T_24242_row12_col1 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_24242_row5_col12, #T_24242_row7_col3, #T_24242_row10_col2 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_24242_row5_col13 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_24242_row6_col7 {
#   background-color: #0566a0;
#   color: #f1f1f1;
# }
# #T_24242_row6_col9 {
#   background-color: #509ac6;
#   color: #f1f1f1;
# }
# #T_24242_row6_col10, #T_24242_row10_col6 {
#   background-color: #88b1d4;
#   color: #000000;
# }
# #T_24242_row6_col11 {
#   background-color: #a9bfdc;
#   color: #000000;
# }
# #T_24242_row6_col12 {
#   background-color: #8fb4d6;
#   color: #000000;
# }
# #T_24242_row7_col0 {
#   background-color: #0f76b3;
#   color: #f1f1f1;
# }
# #T_24242_row7_col6 {
#   background-color: #0567a1;
#   color: #f1f1f1;
# }
# #T_24242_row7_col8 {
#   background-color: #f6eff7;
#   color: #000000;
# }
# #T_24242_row7_col9 {
#   background-color: #2383ba;
#   color: #f1f1f1;
# }
# #T_24242_row7_col10, #T_24242_row7_col12 {
#   background-color: #63a2cb;
#   color: #f1f1f1;
# }
# #T_24242_row7_col11 {
#   background-color: #93b5d6;
#   color: #000000;
# }
# #T_24242_row8_col4 {
#   background-color: #e0deed;
#   color: #000000;
# }
# #T_24242_row8_col6 {
#   background-color: #e3e0ee;
#   color: #000000;
# }
# #T_24242_row8_col10 {
#   background-color: #e0dded;
#   color: #000000;
# }
# #T_24242_row8_col12, #T_24242_row12_col3 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_24242_row9_col0 {
#   background-color: #9ab8d8;
#   color: #000000;
# }
# #T_24242_row9_col4 {
#   background-color: #4094c3;
#   color: #f1f1f1;
# }
# #T_24242_row9_col7 {
#   background-color: #2081b9;
#   color: #f1f1f1;
# }
# #T_24242_row9_col8 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_24242_row9_col10 {
#   background-color: #0569a4;
#   color: #f1f1f1;
# }
# #T_24242_row9_col11 {
#   background-color: #348ebf;
#   color: #f1f1f1;
# }
# #T_24242_row9_col12 {
#   background-color: #0567a2;
#   color: #f1f1f1;
# }
# #T_24242_row10_col4 {
#   background-color: #7dacd1;
#   color: #f1f1f1;
# }
# #T_24242_row10_col7 {
#   background-color: #60a1ca;
#   color: #f1f1f1;
# }
# #T_24242_row10_col9 {
#   background-color: #0569a5;
#   color: #f1f1f1;
# }
# #T_24242_row10_col11 {
#   background-color: #549cc7;
#   color: #f1f1f1;
# }
# #T_24242_row10_col12, #T_24242_row12_col10 {
#   background-color: #056faf;
#   color: #f1f1f1;
# }
# #T_24242_row11_col4 {
#   background-color: #89b1d4;
#   color: #000000;
# }
# #T_24242_row11_col6, #T_24242_row12_col6 {
#   background-color: #8eb3d5;
#   color: #000000;
# }
# #T_24242_row11_col7 {
#   background-color: #78abd0;
#   color: #f1f1f1;
# }
# #T_24242_row11_col8, #T_24242_row12_col5 {
#   background-color: #f5eef6;
#   color: #000000;
# }
# #T_24242_row11_col9 {
#   background-color: #2786bb;
#   color: #f1f1f1;
# }
# #T_24242_row11_col10 {
#   background-color: #3d93c2;
#   color: #f1f1f1;
# }
# #T_24242_row11_col13 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_24242_row12_col4 {
#   background-color: #81aed2;
#   color: #f1f1f1;
# }
# #T_24242_row12_col7 {
#   background-color: #62a2cb;
#   color: #f1f1f1;
# }
# #T_24242_row12_col8 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_24242_row12_col9 {
#   backg

# %%
table = pd.crosstab(emp.Department,columns=emp.Gender)
table
# Out:
# Gender                  Female  Male
# Department
# Human Resources             20    43
# Research & Development     379   582
# Sales                      189   257

# %%
table = pd.crosstab(emp.EducationField,columns=emp.Gender)
table
# Out:
# Gender            Female  Male
# EducationField
# Human Resources        8    19
# Life Sciences        240   366
# Marketing             69    90
# Medical              190   274
# Other                 29    53
# Technical Degree      52    80

# %%
table = pd.crosstab(emp.EducationField,columns=[emp.Department,emp.Attrition])
table
# Out:
# Department       Human Resources    Research & Development     Sales
# Attrition                      0  1                      0   1     0   1
# EducationField
# Human Resources               20  7                      0   0     0   0
# Life Sciences                 15  1                    381  59   121  29
# Marketing                      0  0                      0   0   124  35
# Medical                       11  2                    316  47    74  14
# Other                          3  0                     57   7    11   4
# Technical Degree               2  2                     74  20    24  10

# %%
tab = pd.crosstab(emp.Department,columns=emp.)
tab

# %%
emp.hist(column="MonthlyIncome", by ='Department',figsize=(20,15),bins=15)
plt.show()

# %%
tab = pd.crosstab(emp.EnvironmentSatisfaction,columns='Frequency')
tab
# Out:
# col_0                    Frequency
# EnvironmentSatisfaction
# 1                              284
# 2                              287
# 3                              453
# 4                              446

# %%
tab = pd.crosstab(emp.EnvironmentSatisfaction,columns=emp.Attrition)
tab
# Out:
# Attrition                  0   1
# EnvironmentSatisfaction
# 1                        212  72
# 2                        244  43
# 3                        391  62
# 4                        386  60

# %% [markdown]
# We can see from above table that attrition is not related to enviroment satisfaction.

# %%
tab = pd.crosstab(emp.JobInvolvement,columns='Frequency')
tab
# Out:
# col_0           Frequency
# JobInvolvement
# 1                      83
# 2                     375
# 3                     868
# 4                     144

# %%
tab = pd.crosstab(emp.JobInvolvement,columns=emp.Attrition)
tab
# Out:
# Attrition         0    1
# JobInvolvement
# 1                55   28
# 2               304   71
# 3               743  125
# 4               131   13

# %%
sns.heatmap(pd.crosstab(emp['JobInvolvement'],emp['Attrition']))
# Out:
# <AxesSubplot:xlabel='Attrition', ylabel='JobInvolvement'>

# %% [markdown]
# We can see from the above table that the attrition is least for those employees, who have  very high job involvement('4') and for employees with job involvement '1', attrition is very high

# %%
tab = pd.crosstab(emp.JobSatisfaction,columns='Frequency')
tab
# Out:
# col_0            Frequency
# JobSatisfaction
# 1                      289
# 2                      280
# 3                      442
# 4                      459

# %%
tab = pd.crosstab(emp.JobSatisfaction,columns=emp.Attrition)
tab
# Out:
# Attrition          0   1
# JobSatisfaction
# 1                223  66
# 2                234  46
# 3                369  73
# 4                407  52

# %%
tab = pd.crosstab(emp.JobSatisfaction,columns=[emp.Department,emp.Attrition])
tab
# Out:
# Department      Human Resources    Research & Development     Sales
# Attrition                     0  1                      0   1     0   1
# JobSatisfaction
# 1                             6  5                    154  38    63  23
# 2                            18  2                    150  24    66  20
# 3                            12  3                    257  43   100  27
# 4                            15  2                    267  28   125  22

# %%
tab = pd.crosstab(emp.Department,columns='frequency')
tab
# Out:
# col_0                   frequency
# Department
# Human Resources                63
# Research & Development        961
# Sales                         446

# %%
tab = pd.crosstab(emp.JobLevel,columns='Frequency')
tab
# Out:
# col_0     Frequency
# JobLevel
# 1               543
# 2               534
# 3               218
# 4               106
# 5                69

# %%
tab = pd.crosstab(emp.JobLevel,columns=emp.Attrition)
tab
# Out:
# Attrition    0    1
# JobLevel
# 1          400  143
# 2          482   52
# 3          186   32
# 4          101    5
# 5           64    5

# %%
tab = pd.crosstab(emp.OverTime,columns=emp.Attrition)
tab
# Out:
# Attrition    0    1
# OverTime
# No         944  110
# Yes        289  127

# %%
tab = pd.crosstab(emp.OverTime,columns='frequncy')
tab
# Out:
# col_0     frequncy
# OverTime
# No            1054
# Yes            416

# %%
tab = pd.crosstab(emp.OverTime,columns=emp.Department)
tab
# Out:
# Department  Human Resources  Research & Development  Sales
# OverTime
# No                       46                     690    318
# Yes                      17                     271    128

# %%
tab = pd.crosstab(emp.WorkLifeBalance,columns='frequncy')
tab
# Out:
# col_0            frequncy
# WorkLifeBalance
# 1                      80
# 2                     344
# 3                     893
# 4                     153

# %%
tab = pd.crosstab(emp.WorkLifeBalance,columns=emp.Attrition)
tab
# Out:
# Attrition          0    1
# WorkLifeBalance
# 1                 55   25
# 2                286   58
# 3                766  127
# 4                126   27

# %%
tab = pd.crosstab(emp.MaritalStatus,columns='freq')
tab
# Out:
# col_0          freq
# MaritalStatus
# Divorced        327
# Married         673
# Single          470

# %%
tab = pd.crosstab(emp.MaritalStatus,columns=emp.Attrition)
tab
# Out:
# Attrition        0    1
# MaritalStatus
# Divorced       294   33
# Married        589   84
# Single         350  120

# %%
tab = pd.crosstab(emp.YearsAtCompany,columns=emp.Attrition)
tab
# Out:
# Attrition         0   1
# YearsAtCompany
# 0                28  16
# 1               112  59
# 2               100  27
# 3               108  20
# 4                91  19
# 5               175  21
# 6                67   9
# 7                79  11
# 8                71   9
# 9                74   8
# 10              102  18
# 11               30   2
# 12               14   0
# 13               22   2
# 14               16   2
# 15               19   1
# 16               11   1
# 17                8   1
# 18               12   1
# 19               10   1
# 20               26   1
# 21               13   1
# 22               14   1
# 23                1   1
# 24                5   1
# 25                4   0
# 26                4   0
# 27                2   0
# 29                2   0
# 30                1   0
# 31                2   1
# 32                2   1
# 33                4   1
# 34                1   0
# 36                2   0
# 37                1   0
# 40                0   1

# %%
tab = pd.crosstab(emp.TotalWorkingYears,columns=emp.Attrition)
tab
# Out:
# Attrition             0   1
# YearsInCurrentRole
# 0                   171  73
# 1                    46  11
# 2                   304  68
# 3                   119  16
# 4                    89  15
# 5                    35   1
# 6                    35   2
# 7                   191  31
# 8                    82   7
# 9                    61   6
# 10                   27   2
# 11                   22   0
# 12                    9   1
# 13                   13   1
# 14                   10   1
# 15                    6   2
# 16                    7   0
# 17                    4   0
# 18                    2   0

# %%
tab = pd.crosstab(emp.TotalWorkingYears,columns=emp.Attrition)
tab
# Out:
# Attrition            0   1
# TotalWorkingYears
# 0                    6   5
# 1                   41  40
# 2                   22   9
# 3                   33   9
# 4                   51  12
# 5                   72  16
# 6                  103  22
# 7                   63  18
# 8                   87  16
# 9                   86  10
# 10                 177  25
# 11                  29   7
# 12                  43   5
# 13                  33   3
# 14                  27   4
# 15                  35   5
# 16                  34   3
# 17                  30   3
# 18                  23   4
# 19                  19   3
# 20                  28   2
# 21                  33   1
# 22                  19   2
# 23                  20   2
# 24                  15   3
# 25                  13   1
# 26                  13   1
# 27                   7   0
# 28                  13   1
# 29                  10   0
# 30                   7   0
# 31                   8   1
# 32                   9   0
# 33                   6   1
# 34                   4   1
# 35                   3   0
# 36                   6   0
# 37                   4   0
# 38                   1   0
# 40                   0   2

# %%
tab = pd.crosstab(emp.YearsSinceLastPromotion,columns=emp.Attrition)
tab
# Out:
# Attrition                  0    1
# YearsSinceLastPromotion
# 0                        471  110
# 1                        308   49
# 2                        132   27
# 3                         43    9
# 4                         56    5
# 5                         43    2
# 6                         26    6
# 7                         60   16
# 8                         18    0
# 9                         13    4
# 10                         5    1
# 11                        22    2
# 12                        10    0
# 13                         8    2
# 14                         8    1
# 15                        10    3

# %%
emp['Attrition'].value_counts().plot(kind="bar", figsize=(4,4), color="coral",fontsize=12)
# Out:
# <AxesSubplot:>

# %%
sns.set(style='white')

#create grouped bar chart
sns.barplot(x='Age', hue='Attrition', data=emp,
            palette=['purple', 'steelblue'])

#add overall title
plt.title('Customers by Time & Day of Week', fontsize=16)

#add axis titles
plt.xlabel('Day of Week')
plt.ylabel('Number of Customers')

#rotate x-axis labels
plt.xticks(rotation=45)
# Out:
# (array([ 0.,  5., 10., 15., 20., 25., 30., 35., 40.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
plt.figure(figsize = (9, 5), dpi = 100)
sns.countplot(x='JobInvolvement', hue='Attrition', data=emp,
            palette=['purple', 'steelblue'])
# Out:
# <AxesSubplot:xlabel='JobInvolvement', ylabel='count'>

# %%
plt.figure(figsize = (10, 6), dpi = 100)
sns.countplot(x='EnvironmentSatisfaction', hue='Attrition', data=emp,
            palette=['purple', 'steelblue'])
# Out:
# <AxesSubplot:xlabel='EnvironmentSatisfaction', ylabel='count'>

# %%
plt.figure(figsize = (9, 5), dpi = 100)
sns.countplot(x='JobLevel', hue='Attrition', data=emp,
            palette=['purple', 'steelblue'])
# Out:
# <AxesSubplot:xlabel='JobLevel', ylabel='count'>

# %%
plt.figure(figsize = (9, 5), dpi = 100)
sns.countplot(x='JobSatisfaction', hue='Attrition', data=emp,
            palette=['purple', 'steelblue'])
# Out:
# <AxesSubplot:xlabel='JobSatisfaction', ylabel='count'>

# %%
plt.figure(figsize = (9, 5), dpi = 100)
sns.countplot(x='BusinessTravel', hue='Attrition', data=emp,
            palette=['purple', 'steelblue'])
# Out:
# <AxesSubplot:xlabel='BusinessTravel', ylabel='count'>

# %%
table = pd.crosstab(emp.Attrition,columns=emp.BusinessTravel)
coltotal = table.sum(axis=0)
table.div(coltotal,axis=1)
# Out:
# BusinessTravel  Non-Travel  Travel_Frequently  Travel_Rarely
# Attrition
# 0                     0.92           0.750903       0.850431
# 1                     0.08           0.249097       0.149569

# %%
plt.figure(figsize = (9, 5), dpi = 100)
sns.countplot(x='Department', hue='Attrition', data=emp,
            palette=['purple', 'steelblue'])
# Out:
# <AxesSubplot:xlabel='Department', ylabel='count'>

# %%
plt.figure(figsize = (9, 5), dpi = 100)
sns.countplot(x='EducationField', hue='Attrition', data=emp,
            palette=['purple', 'steelblue'])
# Out:
# <AxesSubplot:xlabel='EducationField', ylabel='count'>

# %%
plt.figure(figsize = (9, 5), dpi = 100)
sns.countplot(x='Gender', hue='Attrition', data=emp,
            palette=['purple', 'steelblue'])
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
plt.figure(figsize = (15, 7), dpi = 100)
sns.countplot(x='Age', hue='Attrition', data=emp,
            palette=['purple', 'steelblue'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %%
sns.distplot(emp[emp['Attrition']==0]['Age'],hist=False,label='0')
sns.distplot(emp[emp['Attrition']==1]['Age'],hist=False,label='1')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
df = emp[emp.Attrition == 0]
sns.distplot(df['Age'], hist = True, kde = True, label='0')
df = emp[emp.Attrition == 1]
sns.distplot(df['Age'], hist = True, kde = True, label='1')
plt.legend(prop={'size': 12})
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Orange -> attrition 1

# %%
a = sns.distplot(emp[emp['Attrition']==0]['MonthlyIncome'],hist=True)
b = sns.distplot(emp[emp['Attrition']==1]['MonthlyIncome'],hist=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
a = sns.distplot(emp[emp['Attrition']==0]['TotalWorkingYears'],hist=False)
b = sns.distplot(emp[emp['Attrition']==1]['TotalWorkingYears'],hist=False)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
emp.plot(kind="scatter",
         x="Age", y = "MonthlyIncome",
         color = "green",
         figsize=(8,7))

plt.xlabel("Age", fontsize=12)
plt.ylabel("MonthlyIncome", fontsize=12)
plt.title("Scatter Plot", fontsize=14)

plt.show()

# %%
YearsInCurrentRole

# %%
a = sns.distplot(emp[emp['Attrition']==0]['YearsAtCompany'],hist=False)
b = sns.distplot(emp[emp['Attrition']==1]['YearsAtCompany'],hist=False)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
a = sns.distplot(emp[emp['Attrition']==0]['YearsInCurrentRole'],hist=False)
b = sns.distplot(emp[emp['Attrition']==1]['YearsInCurrentRole'],hist=False)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
a = sns.distplot(emp[emp['Attrition']==0]['DistanceFromHome'],hist=False)
b = sns.distplot(emp[emp['Attrition']==1]['DistanceFromHome'],hist=False)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
